# %%
from sklearn.datasets import make_regression

# %%
input_, target_ = make_regression(n_samples = 500, n_features = 1, n_informative = 3)

# %% [markdown]
# ### Plotting the dataset

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(input_,target_)
plt.xlabel('input')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')
