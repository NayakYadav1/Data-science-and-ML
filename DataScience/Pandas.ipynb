# %%
import numpy as np
import pandas as pd

# %%
array_a = np.array(['I', 'Love', 'Python'])

# %%
series_from_array = pd.Series(array_a)
series_from_array
# Out:
# 0         I
# 1      Love
# 2    Python
# dtype: object

# %%
type(series_from_array)
# Out:
# pandas.core.series.Series

# %%
series_from_array[2]
# Out:
# 'Python'

# %%
# Creating series with index from array
series_from_array_index = pd.Series(array_a, index = ['a', 'b', 'c'])
series_from_array_index
# Out:
# a         I
# b      Love
# c    Python
# dtype: object

# %%
# same thing different way
# series_from_array_index['c']
series_from_array_index.iloc[2]
# Out:
# 'Python'

# %%
# dataframes
list_a = ['Python', 'Ruby', 'Rust', 'Java', 'PHP']
dataframe_from_list = pd.DataFrame(list_a)
dataframe_from_list
# Out:
#         0
# 0  Python
# 1    Ruby
# 2    Rust
# 3    Java
# 4     PHP

# %%
# to create a column name
dataframe_from_list_col_name = pd.DataFrame(list_a, columns = ['Programming Language'])
dataframe_from_list_col_name
# Out:
#   Programming Language
# 0               Python
# 1                 Ruby
# 2                 Rust
# 3                 Java
# 4                  PHP

# %%
dataframe_from_list_col_name['Programming Language'][2]
# Out:
# 'Rust'

# %%
dataframe_from_list_col_name['Programming Language'].iloc[2]
# Out:
# 'Rust'

# %%
# column pick garnu paresi we use this
dataframe_from_list_col_name.loc[2]
# Out:
# Programming Language    Rust
# Name: 2, dtype: object

# %%
# --------------------------------------
list = np.array(['I', 'Love', 'Python'])
series = pd.Series(list)
series[: 2]
# Out:
# 0       I
# 1    Love
# dtype: object

# %%
dataset = pd.read_csv("Downloads/titanic_train.csv")

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
dataset.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
dataset['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
dataset['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
dataset.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# row and column sount
dataset.shape
# Out:
# (891, 12)

# %%
# total size of data
dataset.size
# Out:
# 10692

# %%
# Filtering Rows
dataset['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Filtering ore than one column
dataset[['Survived', 'Sex']]
# Out:
#      Survived     Sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %%
# fetching data that survived
dataset[dataset['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset[dataset['Survived'] == 1][['Name', 'Pclass']]
# Out:
#                                                   Name  Pclass
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)       2
# ..                                                 ...     ...
# 875                   Najib, Miss. Adele Kiamie "Jane"       3
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)       2
# 887                       Graham, Miss. Margaret Edith       1
# 889                              Behr, Mr. Karl Howell       1
#
# [342 rows x 2 columns]

# %%
# Sorting

# %%
# Handling Missing Data
# Drop the missing data
dataset.shape
# Out:
# (891, 12)

# %%
dataset_dropped_nan = dataset.dropna()
dataset_dropped_nan
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset_dropped_nan.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 1          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# 11         False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 871        False     False   False  False  False  False  False  False   False
# 872        False     False   False  False  False  False  False  False   False
# 879        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dataset_dropped_nan.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill the missing value with constant or scalar value
dataset_with_scalar_filled = dataset.fillna('0')
# dataset_with_scalar_filled = dataset.fillna(mean_age = dataset['Age'].mean())
dataset_with_scalar_filled ['Age'].unique()
# Out:
# array([22.0, 38.0, 26.0, 35.0, '0', 54.0, 2.0, 27.0, 14.0, 4.0, 58.0,
#        20.0, 39.0, 55.0, 31.0, 34.0, 15.0, 28.0, 8.0, 19.0, 40.0, 66.0,
#        42.0, 21.0, 18.0, 3.0, 7.0, 49.0, 29.0, 65.0, 28.5, 5.0, 11.0,
#        45.0, 17.0, 32.0, 16.0, 25.0, 0.83, 30.0, 33.0, 23.0, 24.0, 46.0,
#        59.0, 71.0, 37.0, 47.0, 14.5, 70.5, 32.5, 12.0, 9.0, 36.5, 51.0,
#        55.5, 40.5, 44.0, 1.0, 61.0, 56.0, 50.0, 36.0, 45.5, 20.5, 62.0,
#        41.0, 52.0, 63.0, 23.5, 0.92, 43.0, 60.0, 10.0, 64.0, 13.0, 48.0,
#        0.75, 53.0, 57.0, 80.0, 70.0, 24.5, 6.0, 0.67, 30.5, 0.42, 34.5,
#        74.0], dtype=object)

# %%
# Filling the missing value with aggregated values
dataset_with_mean_filling = dataset.copy()
dataset_with_mean_filling
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset_with_mean_filling['Age'].fillna(dataset_with_mean_filling['Age'].mean(), inplace=True)
dataset_with_mean_filling
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_11876\129478221.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset_with_mean_filling['Age'].fillna(dataset_with_mean_filling['Age'].mean(), inplace=True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# ...

# %%
# Pandas to deal with categorical variables
dataset['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# One hot encoding - add dummy column
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset_one_hot_encoding =
